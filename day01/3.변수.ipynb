# %% [markdown]
# # 1. 변수
# * 변수란 처리할 데이터를 저장시키는 기억장소

# %%
name = '김자바'
age = 20

print(name)
print(age)

name = '홍길동'

print(name)
print(age)
# Out:
# 김자바
# 20
# 홍길동
# 20

# %% [markdown]
# # 2. 변수의 이름을 작성하는 방법
#
# 1. 값을 나타내는 핵심단어
# 2. 반드시 문자로 시작해야하고, 예약어는 사용할 수 없음
# 3. 영문자, 숫자, 특수문자(_)로 사용하며 대소문자를 구별

# %%
num1 = 10
num2 = 3
print('%d / %d = %f' % (num1, num2, num1/num2))
# Out:
# 10 / 3 = 3.333333

# %% [markdown]
# # 3. 변수의 데이터 타입
# * 데이터 타입(자료형) : 자료가 저장되는 형태를 의미

# %%
name = '홍길동'
age = 20
weight = 50.5
isLover = False

# type() : 변수의 데이터 타입을 반환해주는 함수
print(type(name))   # <class 'str'> : 문자형 타입
print(type(age))    # <class 'int'> : 정수형 타입
print(type(weight)) # <class 'float'> : 실수형 타입
print(type(isLover))  # <class 'bool'> : 논리형 타입
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# 변수의 삭제
del isLover
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8698b5afc762> in <cell line: 2>()
#       1 # 변수의 삭제
# ----> 2 del isLover
#
# NameError: name 'isLover' is not defined

# %%
print(isLover)  # NameError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6053910d0aff> in <cell line: 1>()
# ----> 1 print(isLover)
#
# NameError: name 'isLover' is not defined
